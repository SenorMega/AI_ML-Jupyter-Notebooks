# %% [markdown]
# ### Codio Activity 4.5: String Operations
#
#
# **Expected Time: 60 Minutes**
#
# **Total Points: 20**
#
#
# For this activity, you will focus on using string methods on `pandas` series.  Following the examples from video 4.8, a wikipedia page on the states of the russian federation will be the dataset.  Below is a map of the boundaries for the states.
#
# #### Index:
#
# - [Problem 1](#Problem-1)
# - [Problem 2](#Problem-2)
# - [Problem 3](#Problem-3)
# - [Problem 4](#Problem-4)
#
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/7/7d/Map_of_federal_subjects_of_Russia_%282014%29.svg/1380px-Map_of_federal_subjects_of_Russia_%282014%29.svg.png)

# %% [markdown]
# ### Getting the Data
#
# Below, we access the data directly using the url and the `read_html` method from `pandas`.  This method reads any table from a web url in as a list of dataframes.  The data we are interested in is located in the fifth table on the page so we index the list of data accordingly below.

# %%
import pandas as pd

# %%
russian_states = pd.read_csv('data/russian_states.csv', index_col = 0)

# %%
russian_states.head()
# Out:
#    Code                        Name Capital/Administrative centre[a]  Flag  \
# 0     1         Adygea, Republic of                           Maykop   NaN
# 1     2  Bashkortostan, Republic of                              Ufa   NaN
# 2     3       Buryatia, Republic of                         Ulan-Ude   NaN
# 3     4              Altai Republic                    Gorno-Altaysk   NaN
# 4     5       Dagestan, Republic of                      Makhachkala   NaN
#
#    Coatof arms      Type Federal district Economic region Area(km2)[16]  \
# 0          NaN  republic         Southern  North Caucasus          7600
# 1          NaN  republic            Volga            Ural        143600
# 2          NaN  republic      Far Eastern   East Siberian        351300
# 3          NaN  republic         Siberian   West Siberian         92600
# 4          NaN  republic  North Caucasian  North Caucasus         50300
#
#   Population[17]  Populationdensity(/km2)  Yearestablished
# 0         447109                    58.83             1922
# 1        4104336                    28.58             1919
# 2         981238                     2.79             1923
# 3         202947                     2.19             1922
# 4        2576531                    51.22             1921

# %% [markdown]
# [Back to top](#Index:)
#
# ### Problem 1
#
# #### Using the `contains` method
#
# **5 Points**
#
# Use the string method `contains` to subset the data based on entries in the Economic Region column containing `Siberian`.  Assign your response as a DataFrame to `ans1` below.

# %%
### GRADED

ans1 = None

### BEGIN SOLUTION
ans1 = russian_states.loc[russian_states['Economic region'].str.contains("Siberian")]
type(ans1)
### END SOLUTION

# Answer check
print(ans1.shape)
ans1.head()
# Out:
# (15, 12)
#     Code                    Name Capital/Administrative centre[a]  Flag  \
# 2      3   Buryatia, Republic of                         Ulan-Ude   NaN
# 3      4          Altai Republic                    Gorno-Altaysk   NaN
# 16    17           Tuva Republic                            Kyzyl   NaN
# 18    19  Khakassia, Republic of                           Abakan   NaN
# 21    22              Altai Krai                          Barnaul   NaN
#
#     Coatof arms      Type Federal district Economic region Area(km2)[16]  \
# 2           NaN  republic      Far Eastern   East Siberian        351300
# 3           NaN  republic         Siberian   West Siberian         92600
# 16          NaN  republic         Siberian   East Siberian        170500
# 18          NaN  republic         Siberian   East Siberian         61900
# 21          NaN      krai         Siberian   West Siberian        169100
#
#    Population[17]  Populationdensity(/km2)  Yearestablished
# 2          981238                     2.79             1923
# 3          202947                     2.19             1922
# 16         305510                     1.79             1944
# 18         546072                     8.82             1930
# 21        2607426                    15.42             1937

# %%
### BEGIN HIDDEN TESTS
russian_states_ = pd.read_csv('data/russian_states.csv', index_col = 0)
ans1_ = russian_states_.loc[russian_states_['Economic region'].str.contains("Siberian")]
#
#
#
assert type(ans1) == type(ans1_)
pd.testing.assert_frame_equal(ans1, ans1_)
### END HIDDEN TESTS

# %% [markdown]
# [Back to top](#Index:)
#
# ### Problem 2
#
# #### Using the `startswith` method
#
# **5 Points**
#
# Subset the data based on entries in the Economic region column that start with `North`.  Assign your answer as a DataFrame to `ans2` below.

# %%
### GRADED

ans2 = None

### BEGIN SOLUTION
ans2 = russian_states.loc[russian_states['Economic region'].str.startswith('North')]
type(ans2)
### END SOLUTION

# Answer check
print(ans2.shape)
ans2.head(22)
# Out:
# (22, 12)
#     Code                               Name  \
# 0      1                Adygea, Republic of
# 4      5              Dagestan, Republic of
# 5      6            Ingushetia, Republic of
# 6      7          Kabardino-Balkar Republic
# 8      9         Karachay-Cherkess Republic
# 9     10               Karelia, Republic of
# 10    11                      Komi Republic
# 14    15  North Ossetia-Alania, Republic of
# 19    20                   Chechen Republic
# 22    23                     Krasnodar Krai
# 25    26                     Stavropol Krai
# 28    29                 Arkhangelsk Oblast
# 34    35                     Vologda Oblast
# 46    47                   Leningrad Oblast
# 50    51                    Murmansk Oblast
# 52    53                    Novgorod Oblast
# 59    60                       Pskov Oblast
# 60    61                      Rostov Oblast
# 77    78                   Saint Petersburg
# 79    80            Nenets Autonomous Okrug
# 83    84              Republic of Crimea[d]
# 84    85                      Sevastopol[d]
#
#       Capital/Administrative centre[a]  Flag  Coatof arms              Type  \
# 0                               Maykop   NaN          NaN          republic
# 4                          Makhachkala   NaN          NaN          republic
# 5          Magas(Largest city: Nazran)   NaN          NaN          republic
# 6                              Nalchik   NaN          NaN          republic
# 8                            Cherkessk   NaN          NaN          republic
# 9                         Petrozavodsk   NaN          NaN          republic
# 10                           Syktyvkar   NaN          NaN          republic
# 14                         Vladikavkaz   NaN          NaN          republic
# 19                              Grozny   NaN          NaN          republic
# 22                           Krasnodar   NaN          NaN              krai
# 25                           Stavropol   NaN          NaN              krai
# 28                         Arkhangelsk   NaN          NaN            oblast
# 34  Vologda(Largest city: Cherepovets)   NaN          NaN            oblast
# 46           Largest city: Gatchina[b]   NaN          NaN            oblast
# 50                            Murmansk   NaN          NaN            oblast
# 52                     Veliky Novgorod   NaN          NaN            oblast
# 59                               Pskov   NaN          NaN            oblast
# 60                       Rostov-on-Don   NaN          NaN            oblast
# 77                                   —   NaN          NaN      federal city
# 79                          Naryan-Mar   NaN          NaN  autonomous okrug
# 83                          Simferopol   NaN          NaN          republic
# 84                                   —   NaN          NaN      federal city
#
#     Federal district Economic region Area(km2)[16] Population[17]  \
# 0           Southern  North Caucasus          7600         447109
# 4    North Caucasian  North Caucasus         50300        2576531
# 5    North Caucasian  North Caucasus          4000         467294
# 6    North Caucasian  North Caucasus         12500         901494
# 8    North Caucasian  North Caucasus         14100         439470
# 9       Northwestern        Northern        172400         716281
# 10      Northwestern        Northern        415900        1018674
# 14   North Caucasian  North Caucasus          8000         710275
# 19   North Caucasian  North Caucasus         15300        1103686
# 22          Southern  North Caucasus         76000        5125221
# 25   North Caucasian  North Caucasus         66500        2735139
# 28      Northwestern        Northern        587400        1336539
# 34      Northwestern        Northern        145700        1269568
# 46      Northwestern    Northwestern         84500        1669205
# 50      Northwestern        Northern        144900         892534
# 52      Northwestern    Northwestern         55300         694355
# 59      Northwestern    Northwestern         55300         760810
# 60          Southern  North Caucasus        100800        4404013
# 77      Northwestern    Northwestern          1439        4662547
# 79      Northwestern        Northern        176700          41546
# 83  Southern[19][20]  North Caucasus    26,964[21]  1,966,801[22]
# 84  Southern[19][20]  North Caucasus       864[23]    379,200[23]
#
#     Populationdensity(/km2)  Yearestablished
# 0                     58.83             1922
# 4                     51.22             1921
# 5                    116.82             1992
# 6                     72.12             1936
# 8                     31.17             1957
# 9                      4.15             1956
# 10                     2.45             1921
# 14                    88.78             1924
# 19                    72.14             1991
# 22                    67.44             1937
# 25                    41.13             1934
# 28                     2.28             1937
# 34                     8.71             1937
# 46                    19.75             1927
# 50                     6.16             1938
# 52                    12.56             1944
# 59                    13.76             1944
# 60                    43.69             1937
# 77                  3240.13             1703
# 79                     0.24             1929
# 83                    72.94             2014
# 84                   438.89             2014

# %%
### BEGIN HIDDEN TESTS
russian_states_ = pd.read_csv('data/russian_states.csv', index_col = 0)
ans2_ = russian_states_.loc[russian_states_['Economic region'].str.startswith('North')]
#
#
#
assert type(ans2) == type(ans2_)
pd.testing.assert_frame_equal(ans2, ans2_)
### END HIDDEN TESTS

# %% [markdown]
# [Back to top](#Index:)
#
# ### Problem 3: Using the `upper` method
#
# **5 Points**
#
# Use the `upper` method to create a series with the Federal District column all uppercased.  Assign your response as a Series to `ans3` below.

# %%
### GRADED

ans3 = None

### BEGIN SOLUTION
ans3 = russian_states['Federal district'].str.upper()
type(ans3)
### END SOLUTION

# Answer check
print(type(ans3))
ans3.head()
# Out:
# <class 'pandas.core.series.Series'>
# 0           SOUTHERN
# 1              VOLGA
# 2        FAR EASTERN
# 3           SIBERIAN
# 4    NORTH CAUCASIAN
# Name: Federal district, dtype: object

# %%
### BEGIN HIDDEN TESTS
russian_states_ = pd.read_csv('data/russian_states.csv', index_col = 0)
ans3_ = russian_states_['Federal district'].str.upper()
#
#
#
assert type(ans3) == type(ans3_)
pd.testing.assert_series_equal(ans3, ans3_)
### END HIDDEN TESTS

# %% [markdown]
# [Back to top](#Index:)
#
# ### Problem 4
#
# #### Examining the Population
#
# **5 Points**
#
#
# Much like the example in the videos, the Population column contains problematic characters that need to be replaced before the column can be converted to a float datatype.  Replace these values and convert the Population column to float datatypes.  Assign the your response as a series to `ans4` below.
#
# **Note:** Create a new dataframe for your cleaned data. Don’t modify the original russian_states dataframe.

# %%
### GRADED

ans4 = None

### BEGIN SOLUTION
ans4 = russian_states['Population[17]'].str.replace("\[22\]", " ").str.replace("\[23\]", " ").str.replace(',', '').astype('float')
type(ans4)
### END SOLUTION

# Answer check
print(type(ans4))
ans4.head()
# Out:
# <class 'pandas.core.series.Series'>
# /tmp/ipykernel_235/1484786514.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   ans4 = russian_states['Population[17]'].str.replace("\[22\]", " ").str.replace("\[23\]", " ").str.replace(',', '').astype('float')
# 0     447109.0
# 1    4104336.0
# 2     981238.0
# 3     202947.0
# 4    2576531.0
# Name: Population[17], dtype: float64

# %%
### BEGIN HIDDEN TESTS
russian_states_ = pd.read_csv('data/russian_states.csv', index_col = 0)
ans4_ = russian_states_['Population[17]'].str.replace("\[22\]", " ").str.replace("\[23\]", " ").str.replace(',', '').astype('float')

#
#
#
assert type(ans4) == type(ans4_)
pd.testing.assert_series_equal(ans4, ans4_)
### END HIDDEN TESTS
# Out:
# /tmp/ipykernel_235/3131606586.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   ans4_ = russian_states_['Population[17]'].str.replace("\[22\]", " ").str.replace("\[23\]", " ").str.replace(',', '').astype('float')
