# %% [markdown]
# ### Python lists

# %%
[0.1, 0.2, 'a', 'b']
# Out:
# [0.1, 0.2, 'a', 'b']

# %% [markdown]
# ### Numpy array

# %%
import numpy as np

np.array([0.1, 0.2, 0.3, 0.4])
# Out:
# array([0.1, 0.2, 0.3, 0.4])

# %% [markdown]
# ### Pandas DataFrame
#
# ![title](pandas.png)

# %% [markdown]
# ---
# # <center> <font color=purple>[pandas](https://pandas.pydata.org/)  ([docs](https://pandas.pydata.org/pandas-docs/stable/index.html))
# </font>  </center>
# ---

# %% [markdown]
# ## Standard import

# %%
import pandas as pd

# %% [markdown]
# ---
# # <center> <font color=darkgreen>Creating a DataFrame</font></center>
# ---

# %% [markdown]
# ## Create a DataFrame from a dictionary

# %%
df1 = pd.DataFrame({'A':[25,56,93] , 
                    'B':['str1','str7','str3']})

df1
# Out:
#     A     B
# 0  25  str1
# 1  56  str7
# 2  93  str3

# %% [markdown]
# ### Change the index: [`set_index()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.set_index.html)
#
# The default index is a list of integers. Use `set_index()` to assign a column to be the index.

# %%
df2 = df1.set_index('B')
df2
# Out:
#        A
# B
# str1  25
# str7  56
# str3  93

# %% [markdown]
# ## Load data from an external source

# %%
# pd.read_

# %% [markdown]
# ## Load a DataFrame from a file

# %%
CH = pd.read_csv('C:\\Users\sspillane\Desktop\Python Review Jupyter Notebooks\data\celebrity-heights.csv')
CH
# Out:
#         id firstname midname     lastname           fullname        ftin  \
# 0        1     Verne     NaN       Troyer       Verne Troyer     2ft 8in
# 1        8     Herve     NaN  Villechaize  Herve Villechaize    3ft 10in
# 2        9     David     NaN    Rappaport    David Rappaport    3ft 11in
# 3        2      Tony     NaN          Cox           Tony Cox     3ft 6in
# 4        3   Warwick     NaN        Davis      Warwick Davis     3ft 6in
# ...    ...       ...     ...          ...                ...         ...
# 5497  5499   General     NaN       Height     General Height   7ft 6.5in
# 5498  5498   Matthew     NaN      McGrory    Matthew McGrory     7ft 6in
# 5499  5500     Sandy     NaN        Allen        Sandy Allen  7ft 7.25in
# 5500  5501       Sun    Ming         Ming      Sun Ming Ming  7ft 8.75in
# 5501  5502    Robert     NaN       Wadlow      Robert Wadlow    8ft 11in
#
#       feet  inches   meters gender
# 0        2    8.00  0.81280      M
# 1        3   10.00  1.16840      M
# 2        3   11.00  1.19380      M
# 3        3    6.00  1.06680      M
# 4        3    6.00  1.06680      M
# ...    ...     ...      ...    ...
# 5497     7    6.50  2.29870    NaN
# 5498     7    6.00  2.28600      M
# 5499     7    7.25  2.31775      F
# 5500     7    8.75  2.35585    NaN
# 5501     8   11.00  2.71780      M
#
# [5502 rows x 10 columns]

# %%
CH3 = pd.read_csv('C:\\Users\sspillane\Desktop\Python Review Jupyter Notebooks\data\Debernardi et al 2020 data.csv')
CH3.describe()
# Out:
#               age   diagnosis  plasma_CA19_9  creatinine       LYVE1  \
# count  590.000000  590.000000     350.000000  590.000000  590.000000
# mean    59.079661    2.027119     654.002944    0.855383    3.063530
# std     13.109520    0.804873    2430.317642    0.639028    3.438796
# min     26.000000    1.000000       0.000000    0.056550    0.000129
# 25%     50.000000    1.000000       8.000000    0.373230    0.167179
# 50%     60.000000    2.000000      26.500000    0.723840    1.649862
# 75%     69.000000    3.000000     294.000000    1.139482    5.205037
# max     89.000000    3.000000   31000.000000    4.116840   23.890323
#
#              REG1B          TFF1         REG1A
# count   590.000000    590.000000    306.000000
# mean    111.774090    597.868722    735.281222
# std     196.267110   1010.477245   1477.247724
# min       0.001104      0.005293      0.000000
# 25%      10.757216     43.961000     80.692000
# 50%      34.303353    259.873974    208.538500
# 75%     122.741013    742.736000    649.000000
# max    1403.897600  13344.300000  13200.000000

# %%
CH5 = pd.read_csv('C:\\Users\sspillane\Desktop\Python Review Jupyter Notebooks\data\world_population - Master Sheet world_population.csv')
CH5.describe()
# Out:
#        CCA3 Continent Country/Territory 2022 Population 2020 Population  \
# count   234       234               234             234             234
# unique  234         6               233             234             234
# top     AFG    Africa      Saint Martin      41,128,771      38,972,230
# freq      1        57                 2               1               1
#
#        2015 Population 2010 Population 2000 Population 1990 Population  \
# count              234             234             234             234
# unique             234             234             234             234
# top         33,753,499      28,189,672      19,542,982      10,694,796
# freq                 1               1               1               1
#
#        1980 Population 1970 Population Area (km²) Density (per km²)  \
# count              234             234        234               234
# unique             234             234        233               171
# top         12,486,631      10,752,971         21             4 km²
# freq                 1               1          2                 6
#
#        Growth Rate World Population Percentage       Unnamed: 15
# count          234                         234                 1
# unique           9                          70                 1
# top           101%                       0.00%  1,425,887,337.00
# freq            81                          57                 1

# %%
df = pd.read_csv('C:/Users/sspillane/Desktop/Python Review Jupyter Notebooks/data/timeseries.csv')
df
# Out:
#             Date  Consumption     Wind   Solar  Wind+Solar
# 0     2015-01-01   1111.33600  325.128  17.079     342.207
# 1     2015-01-02   1300.88400  603.558   7.758     611.316
# 2     2015-01-03   1265.27100  462.953   7.236     470.189
# 3     2015-01-04   1198.85400  385.024  19.984     405.008
# 4     2015-01-05   1449.86100  216.543  26.524     243.067
# ...          ...          ...      ...     ...         ...
# 1091  2017-12-27   1263.94091  394.507  16.530     411.037
# 1092  2017-12-28   1299.86398  506.424  14.162     520.586
# 1093  2017-12-29   1295.08753  584.277  29.854     614.131
# 1094  2017-12-30   1215.44897  721.247   7.467     728.714
# 1095  2017-12-31   1107.11488  721.176  19.980     741.156
#
# [1096 rows x 5 columns]

# %%
CH4 = pd.read_csv('C:\\Users\sspillane\Desktop\Python Review Jupyter Notebooks\data\ped_crashes.csv')
CH4.describe()
# Out:
#         Crash Year    Crash Day
# count  6809.000000  6809.000000
# mean   2013.992216    15.384197
# std       2.597471     8.701025
# min    2010.000000     1.000000
# 25%    2012.000000     8.000000
# 50%    2014.000000    15.000000
# 75%    2016.000000    23.000000
# max    2018.000000    31.000000

# %%
CH2 = CH.set_index('meters')
CH2
# Out:
#            id firstname midname     lastname           fullname        ftin  \
# meters
# 0.81280     1     Verne     NaN       Troyer       Verne Troyer     2ft 8in
# 1.16840     8     Herve     NaN  Villechaize  Herve Villechaize    3ft 10in
# 1.19380     9     David     NaN    Rappaport    David Rappaport    3ft 11in
# 1.06680     2      Tony     NaN          Cox           Tony Cox     3ft 6in
# 1.06680     3   Warwick     NaN        Davis      Warwick Davis     3ft 6in
# ...       ...       ...     ...          ...                ...         ...
# 2.29870  5499   General     NaN       Height     General Height   7ft 6.5in
# 2.28600  5498   Matthew     NaN      McGrory    Matthew McGrory     7ft 6in
# 2.31775  5500     Sandy     NaN        Allen        Sandy Allen  7ft 7.25in
# 2.35585  5501       Sun    Ming         Ming      Sun Ming Ming  7ft 8.75in
# 2.71780  5502    Robert     NaN       Wadlow      Robert Wadlow    8ft 11in
#
#          feet  inches gender
# meters
# 0.81280     2    8.00      M
# 1.16840     3   10.00      M
# 1.19380     3   11.00      M
# 1.06680     3    6.00      M
# 1.06680     3    6.00      M
# ...       ...     ...    ...
# 2.29870     7    6.50    NaN
# 2.28600     7    6.00      M
# 2.31775     7    7.25      F
# 2.35585     7    8.75    NaN
# 2.71780     8   11.00      M
#
# [5502 rows x 9 columns]

# %% [markdown]
# ## Load a DataFrame from online data
#
# + We will load data on eductional attainment and personal income from the [California Open Data](https://data.ca.gov/dataset/ca-educational-attainment-personal-income/resource/26201f19-4469-4311-a819-bbbd3e557eda) portal.
# + Go to the website, copy the URL and enter it below.

# %%
url = 'https://data.ca.gov/dataset/cea8cd18-9d21-4676-85de-d504ee2d4aab/resource/26201f19-4469-4311-a819-bbbd3e557eda/download/ca-educational-attainment-personal-income-2008-2014.csv'
table = pd.read_csv(url)

# %%
table
# Out:
#                         Year        Age  Gender       Educational Attainment  \
# 0     01/01/2008 12:00:00 AM   00 to 17    Male            Children under 15
# 1     01/01/2008 12:00:00 AM   00 to 17    Male       No high school diploma
# 2     01/01/2008 12:00:00 AM   00 to 17    Male       No high school diploma
# 3     01/01/2008 12:00:00 AM   00 to 17    Male       No high school diploma
# 4     01/01/2008 12:00:00 AM   00 to 17    Male       No high school diploma
# ...                      ...        ...     ...                          ...
# 1055  01/01/2014 12:00:00 AM  65 to 80+  Female  Bachelor's degree or higher
# 1056  01/01/2014 12:00:00 AM  65 to 80+  Female  Bachelor's degree or higher
# 1057  01/01/2014 12:00:00 AM  65 to 80+  Female  Bachelor's degree or higher
# 1058  01/01/2014 12:00:00 AM  65 to 80+  Female  Bachelor's degree or higher
# 1059  01/01/2014 12:00:00 AM  65 to 80+  Female  Bachelor's degree or higher
#
#          Personal Income  Population Count
# 0              No Income               NaN
# 1              No Income          650889.0
# 2       $5,000 to $9,999           30152.0
# 3     $10,000 to $14,999            7092.0
# 4     $15,000 to $24,999            3974.0
# ...                  ...               ...
# 1055  $15,000 to $24,999           82988.0
# 1056  $25,000 to $34,999           59607.0
# 1057  $35,000 to $49,999          113584.0
# 1058  $50,000 to $74,999           97657.0
# 1059    $75,000 and over          110009.0
#
# [1060 rows x 6 columns]

# %% [markdown]
# ## DataFrame summaries
# + [info()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.info.html#): Column data types.
# + [describe()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.describe.html#): Summary statistics for numerical columns
# + [head()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.head.html), [tail()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.tail.html#pandas.DataFrame.tail) : Show first or last few rows of a table

# %%
table.tail(10)
# Out:
#                         Year        Age  Gender  \
# 1050  01/01/2014 12:00:00 AM  65 to 80+  Female
# 1051  01/01/2014 12:00:00 AM  65 to 80+  Female
# 1052  01/01/2014 12:00:00 AM  65 to 80+  Female
# 1053  01/01/2014 12:00:00 AM  65 to 80+  Female
# 1054  01/01/2014 12:00:00 AM  65 to 80+  Female
# 1055  01/01/2014 12:00:00 AM  65 to 80+  Female
# 1056  01/01/2014 12:00:00 AM  65 to 80+  Female
# 1057  01/01/2014 12:00:00 AM  65 to 80+  Female
# 1058  01/01/2014 12:00:00 AM  65 to 80+  Female
# 1059  01/01/2014 12:00:00 AM  65 to 80+  Female
#
#                    Educational Attainment     Personal Income  \
# 1050  Some college, less than 4-yr degree  $50,000 to $74,999
# 1051  Some college, less than 4-yr degree    $75,000 and over
# 1052          Bachelor's degree or higher           No Income
# 1053          Bachelor's degree or higher    $5,000 to $9,999
# 1054          Bachelor's degree or higher  $10,000 to $14,999
# 1055          Bachelor's degree or higher  $15,000 to $24,999
# 1056          Bachelor's degree or higher  $25,000 to $34,999
# 1057          Bachelor's degree or higher  $35,000 to $49,999
# 1058          Bachelor's degree or higher  $50,000 to $74,999
# 1059          Bachelor's degree or higher    $75,000 and over
#
#       Population Count
# 1050           63144.0
# 1051           54704.0
# 1052           15459.0
# 1053           62471.0
# 1054          104583.0
# 1055           82988.0
# 1056           59607.0
# 1057          113584.0
# 1058           97657.0
# 1059          110009.0

# %% [markdown]
# ---
# # <center> <font color=darkgreen>Selecting data</font>  </center>
# ---
#
# There are three basic ways to select data from a DataFrame.
#
# + `[]`: Bracket selection
# + `.loc[]` : Label-based selection
# + `.iloc[]` : Integer-based selection

# %% [markdown]
# ## `[]` Bracket selection
#
# Syntax: `X[selector]`
# + To select columns the `selector` can be
#     + A column label (string)
#     + A list of column labels (list of strings)
# + To select rows the `selector` can be
#     + A slice
#     + A boolean mask

# %% [markdown]
# ### Select a single column (string)

# %%
#note the double [[]]
CH[['firstname','lastname']]
# Out:
#         firstname     lastname
# meters
# 0.81280     Verne       Troyer
# 1.16840     Herve  Villechaize
# 1.19380     David    Rappaport
# 1.06680      Tony          Cox
# 1.06680   Warwick        Davis
# ...           ...          ...
# 2.29870   General       Height
# 2.28600   Matthew      McGrory
# 2.31775     Sandy        Allen
# 2.35585       Sun         Ming
# 2.71780    Robert       Wadlow
#
# [5502 rows x 2 columns]

# %%
CH['firstname']
# Out:
# meters
# 0.81280      Verne
# 1.16840      Herve
# 1.19380      David
# 1.06680       Tony
# 1.06680    Warwick
#             ...
# 2.29870    General
# 2.28600    Matthew
# 2.31775      Sandy
# 2.35585        Sun
# 2.71780     Robert
# Name: firstname, Length: 5502, dtype: object

# %% [markdown]
# ### Select multiple columns (list of strings)

# %%
type(CH[['firstname','lastname']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Select rows with slice indexing
# [Slice indexing](https://docs.python.org/3/tutorial/introduction.html), in which you specify a start index, a stop index, and a step, works in the same way in Pandas as it does for regaular Python lists.

# %%
CH[:4]
# Out:
#    id firstname midname     lastname           fullname      ftin  feet  \
# 0   1     Verne     NaN       Troyer       Verne Troyer   2ft 8in     2
# 1   8     Herve     NaN  Villechaize  Herve Villechaize  3ft 10in     3
# 2   9     David     NaN    Rappaport    David Rappaport  3ft 11in     3
# 3   2      Tony     NaN          Cox           Tony Cox   3ft 6in     3
#
#    inches  meters gender
# 0     8.0  0.8128      M
# 1    10.0  1.1684      M
# 2    11.0  1.1938      M
# 3     6.0  1.0668      M

# %% [markdown]
# ### Select rows with a boolean mask
#
# You can use a boolean list or a boolean Series as a mask for filtering rows.

# %%
#returns boolean result of whether the condition is true for all items in that column
CH['meters']>2
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5497     True
# 5498     True
# 5499     True
# 5500     True
# 5501     True
# Name: meters, Length: 5502, dtype: bool

# %%
#full list of all players with meters>2
CH[ CH['meters']>2 ]
# Out:
#         id  firstname midname     lastname             fullname         ftin  \
# 4588  5480      Randy     NaN      Johnson        Randy Johnson     6ft 10in
# 4589  5481     Nathan     NaN        Jones         Nathan Jones     6ft 10in
# 4590  5483      Kevin     NaN      Garnett        Kevin Garnett  6ft 11.75in
# 4591  5482    Nicolai     NaN       Valuev       Nicolai Valuev     6ft 11in
# 5460  5468     LeBron     NaN        James         LeBron James   6ft 7.25in
# 5461  5469      Peter     NaN       Crouch         Peter Crouch    6ft 7.5in
# 5462  5470       Kane     NaN          NaN                Kane     6ft 7.5in
# 5463  5471        The     NaN   Undertaker       The Undertaker    6ft 7.5in
# 5464  5457      James     NaN       Arness         James Arness      6ft 7in
# 5465  5458    Abraham     NaN      Benrubi      Abraham Benrubi      6ft 7in
# 5466  5459     Daniel     NaN      Cudmore       Daniel Cudmore      6ft 7in
# 5467  5460        Sid     NaN         Eudy             Sid Eudy      6ft 7in
# 5468  5461     Vitali     NaN    Klitschko     Vitali Klitschko      6ft 7in
# 5469  5462       John     NaN     Matuszak        John Matuszak      6ft 7in
# 5470  5463    Stephen     NaN     Merchant     Stephen Merchant      6ft 7in
# 5471  5464     Mickey     NaN       Morton        Mickey Morton      6ft 7in
# 5472  5465      Krist     NaN    Novoselic      Krist Novoselic      6ft 7in
# 5473  5466       Tony     NaN      Robbins         Tony Robbins      6ft 7in
# 5474  5467      Bubba     NaN        Smith          Bubba Smith      6ft 7in
# 5475  5475       Brad     NaN      Garrett         Brad Garrett   6ft 8.25in
# 5476  5472    Montell     NaN       Jordan       Montell Jordan      6ft 8in
# 5477  5473      Tyler     NaN         Mane           Tyler Mane      6ft 8in
# 5478  5474    Richard     NaN         Moll         Richard Moll      6ft 8in
# 5479  5479    Michael     NaN       Kingma       Michael Kingma    6ft 9.5in
# 5480  5476        Ted     NaN      Cassidy          Ted Cassidy      6ft 9in
# 5481  5477    Michael     NaN     Crichton     Michael Crichton      6ft 9in
# 5482  5478      Kevin     NaN         Nash           Kevin Nash      6ft 9in
# 5483  5484      Andre     The        Giant      Andre The Giant      7ft 0in
# 5484  5485      Peter     NaN       Mayhew         Peter Mayhew      7ft 0in
# 5485  5486       Tiny     NaN          Ron             Tiny Ron      7ft 0in
# 5486  5487        Big     NaN         Show             Big Show      7ft 0in
# 5487  5488      Carel     NaN    Struycken      Carel Struycken      7ft 0in
# 5488  5493       Wilt     NaN  Chamberlain     Wilt Chamberlain   7ft 1.06in
# 5489  5494    Richard     NaN         Kiel         Richard Kiel    7ft 1.5in
# 5490  5495     Kareem   Abdul       Jabbar  Kareem Abdul Jabbar  7ft 1.625in
# 5491  5489  Shaquille     NaN       O'Neal     Shaquille O'Neal      7ft 1in
# 5492  5490      Dalip     NaN        Singh          Dalip Singh      7ft 1in
# 5493  5491   Football     NaN       Soccer      Football Soccer      7ft 1in
# 5494  5492        Ian     NaN        Whyte            Ian Whyte      7ft 1in
# 5495  5496      Kevin   Peter         Hall     Kevin Peter Hall      7ft 2in
# 5496  5497       Ming     NaN          Yao             Ming Yao      7ft 5in
# 5497  5499    General     NaN       Height       General Height    7ft 6.5in
# 5498  5498    Matthew     NaN      McGrory      Matthew McGrory      7ft 6in
# 5499  5500      Sandy     NaN        Allen          Sandy Allen   7ft 7.25in
# 5500  5501        Sun    Ming         Ming        Sun Ming Ming   7ft 8.75in
# 5501  5502     Robert     NaN       Wadlow        Robert Wadlow     8ft 11in
#
#       feet  inches    meters gender
# 4588     6  10.000  2.082800      M
# 4589     6  10.000  2.082800      M
# 4590     6  11.750  2.127250      M
# 4591     6  11.000  2.108200    NaN
# 5460     6   7.250  2.012950    NaN
# 5461     6   7.500  2.019300      M
# 5462     6   7.500  2.019300      M
# 5463     6   7.500  2.019300    NaN
# 5464     6   7.000  2.006600      M
# 5465     6   7.000  2.006600      M
# 5466     6   7.000  2.006600      M
# 5467     6   7.000  2.006600      M
# 5468     6   7.000  2.006600      M
# 5469     6   7.000  2.006600      M
# 5470     6   7.000  2.006600      M
# 5471     6   7.000  2.006600      F
# 5472     6   7.000  2.006600    NaN
# 5473     6   7.000  2.006600      M
# 5474     6   7.000  2.006600    NaN
# 5475     6   8.250  2.038350      M
# 5476     6   8.000  2.032000    NaN
# 5477     6   8.000  2.032000      M
# 5478     6   8.000  2.032000      M
# 5479     6   9.500  2.070100      M
# 5480     6   9.000  2.057400      M
# 5481     6   9.000  2.057400      M
# 5482     6   9.000  2.057400      M
# 5483     7   0.000  2.133600      M
# 5484     7   0.000  2.133600      M
# 5485     7   0.000  2.133600    NaN
# 5486     7   0.000  2.133600    NaN
# 5487     7   0.000  2.133600    NaN
# 5488     7   1.060  2.160524    NaN
# 5489     7   1.500  2.171700      M
# 5490     7   1.625  2.174875      M
# 5491     7   1.000  2.159000      M
# 5492     7   1.000  2.159000    NaN
# 5493     7   1.000  2.159000    NaN
# 5494     7   1.000  2.159000      M
# 5495     7   2.000  2.184400      M
# 5496     7   5.000  2.260600      F
# 5497     7   6.500  2.298700    NaN
# 5498     7   6.000  2.286000      M
# 5499     7   7.250  2.317750      F
# 5500     7   8.750  2.355850    NaN
# 5501     8  11.000  2.717800      M

# %% [markdown]
# ## `loc[]` : Label-based selection
#
# Syntax: `X.loc[rowselector,columnselector]` (`columnselector` is optional)
#
# `rowselector` can be
# + An index (integer, string, date, etc.)
# + A list of indexes.
# + A slice (only if the index is integer-based)
# + A boolean mask
#
# `columnselector` can be
# + A string label.
# + A list of strings labels.

# %% [markdown]
# ### `.loc` can do (almost) anything `[]` can do
#
# + Except: .loc(slice) only works if the index is the integer-based default index.
# + For column selection, use `.loc[:,columnselector]`

# %%
CH.loc[:7]
# Out:
#    id firstname midname     lastname            fullname      ftin  feet  \
# 0   1     Verne     NaN       Troyer        Verne Troyer   2ft 8in     2
# 1   8     Herve     NaN  Villechaize   Herve Villechaize  3ft 10in     3
# 2   9     David     NaN    Rappaport     David Rappaport  3ft 11in     3
# 3   2      Tony     NaN          Cox            Tony Cox   3ft 6in     3
# 4   3   Warwick     NaN        Davis       Warwick Davis   3ft 6in     3
# 5   4      Phil     NaN    Fondacaro      Phil Fondacaro   3ft 6in     3
# 6   5   Michael       J     Anderson  Michael J Anderson   3ft 7in     3
# 7   6     Kenny     NaN        Baker         Kenny Baker   3ft 8in     3
#
#    inches  meters gender
# 0     8.0  0.8128      M
# 1    10.0  1.1684      M
# 2    11.0  1.1938      M
# 3     6.0  1.0668      M
# 4     6.0  1.0668      M
# 5     6.0  1.0668      M
# 6     7.0  1.0922      M
# 7     8.0  1.1176      M

# %% [markdown]
# ### Example: Select multiple rows and columns

# %%
CH.loc[3:7]
# Out:
#    id firstname midname   lastname            fullname     ftin  feet  inches  \
# 3   2      Tony     NaN        Cox            Tony Cox  3ft 6in     3     6.0
# 4   3   Warwick     NaN      Davis       Warwick Davis  3ft 6in     3     6.0
# 5   4      Phil     NaN  Fondacaro      Phil Fondacaro  3ft 6in     3     6.0
# 6   5   Michael       J   Anderson  Michael J Anderson  3ft 7in     3     7.0
# 7   6     Kenny     NaN      Baker         Kenny Baker  3ft 8in     3     8.0
#
#    meters gender
# 3  1.0668      M
# 4  1.0668      M
# 5  1.0668      M
# 6  1.0922      M
# 7  1.1176      M

# %%
CH.loc[ [0,3,5,7] ]
# Out:
#    id firstname midname   lastname        fullname     ftin  feet  inches  \
# 0   1     Verne     NaN     Troyer    Verne Troyer  2ft 8in     2     8.0
# 3   2      Tony     NaN        Cox        Tony Cox  3ft 6in     3     6.0
# 5   4      Phil     NaN  Fondacaro  Phil Fondacaro  3ft 6in     3     6.0
# 7   6     Kenny     NaN      Baker     Kenny Baker  3ft 8in     3     8.0
#
#    meters gender
# 0  0.8128      M
# 3  1.0668      M
# 5  1.0668      M
# 7  1.1176      M

# %%
CH
# Out:
#         id firstname midname     lastname           fullname        ftin  \
# 0        1     Verne     NaN       Troyer       Verne Troyer     2ft 8in
# 1        8     Herve     NaN  Villechaize  Herve Villechaize    3ft 10in
# 2        9     David     NaN    Rappaport    David Rappaport    3ft 11in
# 3        2      Tony     NaN          Cox           Tony Cox     3ft 6in
# 4        3   Warwick     NaN        Davis      Warwick Davis     3ft 6in
# ...    ...       ...     ...          ...                ...         ...
# 5497  5499   General     NaN       Height     General Height   7ft 6.5in
# 5498  5498   Matthew     NaN      McGrory    Matthew McGrory     7ft 6in
# 5499  5500     Sandy     NaN        Allen        Sandy Allen  7ft 7.25in
# 5500  5501       Sun    Ming         Ming      Sun Ming Ming  7ft 8.75in
# 5501  5502    Robert     NaN       Wadlow      Robert Wadlow    8ft 11in
#
#       feet  inches   meters gender
# 0        2    8.00  0.81280      M
# 1        3   10.00  1.16840      M
# 2        3   11.00  1.19380      M
# 3        3    6.00  1.06680      M
# 4        3    6.00  1.06680      M
# ...    ...     ...      ...    ...
# 5497     7    6.50  2.29870    NaN
# 5498     7    6.00  2.28600      M
# 5499     7    7.25  2.31775      F
# 5500     7    8.75  2.35585    NaN
# 5501     8   11.00  2.71780      M
#
# [5502 rows x 10 columns]

# %%
CH2 = CH.set_index('fullname')

# %%
CH2
# Out:
#                      id firstname midname     lastname        ftin  feet  \
# fullname
# Verne Troyer          1     Verne     NaN       Troyer     2ft 8in     2
# Herve Villechaize     8     Herve     NaN  Villechaize    3ft 10in     3
# David Rappaport       9     David     NaN    Rappaport    3ft 11in     3
# Tony Cox              2      Tony     NaN          Cox     3ft 6in     3
# Warwick Davis         3   Warwick     NaN        Davis     3ft 6in     3
# ...                 ...       ...     ...          ...         ...   ...
# General Height     5499   General     NaN       Height   7ft 6.5in     7
# Matthew McGrory    5498   Matthew     NaN      McGrory     7ft 6in     7
# Sandy Allen        5500     Sandy     NaN        Allen  7ft 7.25in     7
# Sun Ming Ming      5501       Sun    Ming         Ming  7ft 8.75in     7
# Robert Wadlow      5502    Robert     NaN       Wadlow    8ft 11in     8
#
#                    inches   meters gender
# fullname
# Verne Troyer         8.00  0.81280      M
# Herve Villechaize   10.00  1.16840      M
# David Rappaport     11.00  1.19380      M
# Tony Cox             6.00  1.06680      M
# Warwick Davis        6.00  1.06680      M
# ...                   ...      ...    ...
# General Height       6.50  2.29870    NaN
# Matthew McGrory      6.00  2.28600      M
# Sandy Allen          7.25  2.31775      F
# Sun Ming Ming        8.75  2.35585    NaN
# Robert Wadlow       11.00  2.71780      M
#
# [5502 rows x 9 columns]

# %%
CH2.loc['David Rappaport']
# Out:
# id                   9
# firstname        David
# midname            NaN
# lastname     Rappaport
# ftin          3ft 11in
# feet                 3
# inches            11.0
# meters          1.1938
# gender               M
# Name: David Rappaport, dtype: object

# %%
CH2.loc[['David Rappaport','Warwick Davis']]
# Out:
#                  id firstname midname   lastname      ftin  feet  inches  \
# fullname
# David Rappaport   9     David     NaN  Rappaport  3ft 11in     3    11.0
# Warwick Davis     3   Warwick     NaN      Davis   3ft 6in     3     6.0
#
#                  meters gender
# fullname
# David Rappaport  1.1938      M
# Warwick Davis    1.0668      M

# %%
CH2.loc[['David Rappaport','Warwick Davis'],['midname','lastname']]
# Out:
#                 midname   lastname
# fullname
# David Rappaport     NaN  Rappaport
# Warwick Davis       NaN      Davis

# %% [markdown]
# ### Example: Boolean masking

# %%
CH.loc[ CH['meters']>2.1 ]
# Out:
#         id  firstname midname     lastname             fullname         ftin  \
# 4590  5483      Kevin     NaN      Garnett        Kevin Garnett  6ft 11.75in
# 4591  5482    Nicolai     NaN       Valuev       Nicolai Valuev     6ft 11in
# 5483  5484      Andre     The        Giant      Andre The Giant      7ft 0in
# 5484  5485      Peter     NaN       Mayhew         Peter Mayhew      7ft 0in
# 5485  5486       Tiny     NaN          Ron             Tiny Ron      7ft 0in
# 5486  5487        Big     NaN         Show             Big Show      7ft 0in
# 5487  5488      Carel     NaN    Struycken      Carel Struycken      7ft 0in
# 5488  5493       Wilt     NaN  Chamberlain     Wilt Chamberlain   7ft 1.06in
# 5489  5494    Richard     NaN         Kiel         Richard Kiel    7ft 1.5in
# 5490  5495     Kareem   Abdul       Jabbar  Kareem Abdul Jabbar  7ft 1.625in
# 5491  5489  Shaquille     NaN       O'Neal     Shaquille O'Neal      7ft 1in
# 5492  5490      Dalip     NaN        Singh          Dalip Singh      7ft 1in
# 5493  5491   Football     NaN       Soccer      Football Soccer      7ft 1in
# 5494  5492        Ian     NaN        Whyte            Ian Whyte      7ft 1in
# 5495  5496      Kevin   Peter         Hall     Kevin Peter Hall      7ft 2in
# 5496  5497       Ming     NaN          Yao             Ming Yao      7ft 5in
# 5497  5499    General     NaN       Height       General Height    7ft 6.5in
# 5498  5498    Matthew     NaN      McGrory      Matthew McGrory      7ft 6in
# 5499  5500      Sandy     NaN        Allen          Sandy Allen   7ft 7.25in
# 5500  5501        Sun    Ming         Ming        Sun Ming Ming   7ft 8.75in
# 5501  5502     Robert     NaN       Wadlow        Robert Wadlow     8ft 11in
#
#       feet  inches    meters gender
# 4590     6  11.750  2.127250      M
# 4591     6  11.000  2.108200    NaN
# 5483     7   0.000  2.133600      M
# 5484     7   0.000  2.133600      M
# 5485     7   0.000  2.133600    NaN
# 5486     7   0.000  2.133600    NaN
# 5487     7   0.000  2.133600    NaN
# 5488     7   1.060  2.160524    NaN
# 5489     7   1.500  2.171700      M
# 5490     7   1.625  2.174875      M
# 5491     7   1.000  2.159000      M
# 5492     7   1.000  2.159000    NaN
# 5493     7   1.000  2.159000    NaN
# 5494     7   1.000  2.159000      M
# 5495     7   2.000  2.184400      M
# 5496     7   5.000  2.260600      F
# 5497     7   6.500  2.298700    NaN
# 5498     7   6.000  2.286000      M
# 5499     7   7.250  2.317750      F
# 5500     7   8.750  2.355850    NaN
# 5501     8  11.000  2.717800      M

# %%
CH.loc[ CH['meters']>2.1 , ['midname','lastname'] ]
# Out:
#      midname     lastname
# 4590     NaN      Garnett
# 4591     NaN       Valuev
# 5483     The        Giant
# 5484     NaN       Mayhew
# 5485     NaN          Ron
# 5486     NaN         Show
# 5487     NaN    Struycken
# 5488     NaN  Chamberlain
# 5489     NaN         Kiel
# 5490   Abdul       Jabbar
# 5491     NaN       O'Neal
# 5492     NaN        Singh
# 5493     NaN       Soccer
# 5494     NaN        Whyte
# 5495   Peter         Hall
# 5496     NaN          Yao
# 5497     NaN       Height
# 5498     NaN      McGrory
# 5499     NaN        Allen
# 5500    Ming         Ming
# 5501     NaN       Wadlow

# %% [markdown]
# ## `iloc[]`:  Integer-based selection
#
# Syntax: `iloc[rowselector,columnselector]` (`columnselector` is optional)
#
# `rowselector` and `columnselector` can be
# + An integer or list of integers
# + A slice
#
#
# ### Examples

# %%
#this is great when our data has integer row and column indices
CH.iloc[:10,[1,2]]
# Out:
#                    firstname midname
# fullname
# Verne Troyer           Verne     NaN
# Herve Villechaize      Herve     NaN
# David Rappaport        David     NaN
# Tony Cox                Tony     NaN
# Warwick Davis        Warwick     NaN
# Phil Fondacaro          Phil     NaN
# Michael J Anderson   Michael       J
# Kenny Baker            Kenny     NaN
# Billy Barty            Billy     NaN
# Kiran Shah             Kiran     NaN

# %%
#select by using a list of rows, then a list of columns
CH.iloc[[0,10,20],:4]
# Out:
#     id firstname midname lastname
# 0    1     Verne     NaN   Troyer
# 10  17     Nikki     NaN  Blonsky
# 20  21  Adrienne     NaN   Bailon

# %%
#slice of rows and slice of columns
CH.iloc[:4,3:6]
# Out:
#       lastname           fullname      ftin
# 0       Troyer       Verne Troyer   2ft 8in
# 1  Villechaize  Herve Villechaize  3ft 10in
# 2    Rappaport    David Rappaport  3ft 11in
# 3          Cox           Tony Cox   3ft 6in

# %%
CH.iloc[:4]
# Out:
#    id firstname midname     lastname           fullname      ftin  feet  \
# 0   1     Verne     NaN       Troyer       Verne Troyer   2ft 8in     2
# 1   8     Herve     NaN  Villechaize  Herve Villechaize  3ft 10in     3
# 2   9     David     NaN    Rappaport    David Rappaport  3ft 11in     3
# 3   2      Tony     NaN          Cox           Tony Cox   3ft 6in     3
#
#    inches  meters gender
# 0     8.0  0.8128      M
# 1    10.0  1.1684      M
# 2    11.0  1.1938      M
# 3     6.0  1.0668      M
