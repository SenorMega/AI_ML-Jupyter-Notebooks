# %%
import pandas as pd
import seaborn as sns
import plotly.express as px

pd.options.display.max_rows = 10

gdp = pd.read_csv("data/gdp.csv")
print(gdp)
gdp["gdp"] = gdp["GDP (constant 2010 US$)"] / 1_000_000_000

px.line(gdp, x="Year", y="gdp", color = "Entity")


#Now let's find GDP per capita, but the data set doesn't have population
#So, let's get it from another data set
pop = pd.read_csv("data/population.csv")
print(pop)

px.line(pop, x="Year", y="Total population (Gapminder, HYDE & UN)", color="Entity")
#for a more recent history
px.line(pop.query("Year > 1900"), x="Year", y="Total population (Gapminder, HYDE & UN)", color="Entity")

pop = pop.rename(columns = {"Total population (Gapminder, HYDE & UN)" : "population"})
pop

gdp2017 = gdp.query("Year == 2017")
pop2017 = pop.query("Year == 2017")

#This doesn't work
#percapita = gdp2017 / pop2017
# What we want to do is merge the tables
gdp_and_pop_2017 = pd.merge(left=gdp2017, right=pop2017, left_on="Entity", right_on="Entity", how="outer")
gdp_and_pop_2017

#then
gdp_and_pop_2017["gdp per capita"] = gdp_and_pop_2017["GDP (constant 2010 US$)"] / gdp_and_pop_2017["population"]
gdp_and_pop_2017
# Out:
#            Entity Code  Year  GDP (constant 2010 US$)
# 0     Afghanistan  AFG  2002             8.013233e+09
# 1     Afghanistan  AFG  2003             8.689884e+09
# 2     Afghanistan  AFG  2004             8.781610e+09
# 3     Afghanistan  AFG  2005             9.762979e+09
# 4     Afghanistan  AFG  2006             1.030523e+10
# ...           ...  ...   ...                      ...
# 8864     Zimbabwe  ZWE  2013             1.418193e+10
# 8865     Zimbabwe  ZWE  2014             1.448359e+10
# 8866     Zimbabwe  ZWE  2015             1.472830e+10
# 8867     Zimbabwe  ZWE  2016             1.481899e+10
# 8868     Zimbabwe  ZWE  2017             1.532981e+10
#
# [8869 rows x 4 columns]
#             Entity Code  Year  Total population (Gapminder, HYDE & UN)
# 0      Afghanistan  AFG  1800                                  3280000
# 1      Afghanistan  AFG  1801                                  3280000
# 2      Afghanistan  AFG  1802                                  3280000
# 3      Afghanistan  AFG  1803                                  3280000
# 4      Afghanistan  AFG  1804                                  3280000
# ...            ...  ...   ...                                      ...
# 46878     Zimbabwe  ZWE  2015                                 13815000
# 46879     Zimbabwe  ZWE  2016                                 14030000
# 46880     Zimbabwe  ZWE  2017                                 14237000
# 46881     Zimbabwe  ZWE  2018                                 14439000
# 46882     Zimbabwe  ZWE  2019                                 14645000
#
# [46883 rows x 4 columns]
#                 Entity Code_x  Year_x  GDP (constant 2010 US$)         gdp  \
# 0          Afghanistan    AFG  2017.0             2.196941e+10   21.969414
# 1              Albania    ALB  2017.0             1.398856e+10   13.988556
# 2              Algeria    DZA  2017.0             1.993674e+11  199.367414
# 3              Andorra    AND  2017.0             3.382068e+09    3.382068
# 4               Angola    AGO  2017.0             1.037860e+11  103.785984
# ..                 ...    ...     ...                      ...         ...
# 238          Venezuela    NaN     NaN                      NaN         NaN
# 239  Wallis and Futuna    NaN     NaN                      NaN         NaN
# 240     Western Sahara    NaN     NaN                      NaN         NaN
# 241              World    NaN     NaN                      NaN         NaN
# 242              Yemen    NaN     NaN                      NaN         NaN
#
#        Code_y  Year_y    population  gdp per capita
# 0         AFG  2017.0  3.629600e+07      605.284718
# 1         ALB  2017.0  2.884000e+06     4850.400743
# 2         DZA  2017.0  4.138900e+07     4816.917876
# 3         AND  2017.0  7.700000e+04    43922.964124
# 4         AGO  2017.0  2.981700e+07     3480.765485
# ..        ...     ...           ...             ...
# 238       VEN  2017.0  2.940200e+07             NaN
# 239       WLF  2017.0  1.200000e+04             NaN
# 240       ESH  2017.0  5.530000e+05             NaN
# 241  OWID_WRL  2017.0  7.547859e+09             NaN
# 242       YEM  2017.0  2.783500e+07             NaN
#
# [243 rows x 9 columns]

# %%
gdp_and_pop_2017.sort_values("gdp per capita")
# Out:
#                            Entity Code_x  Year_x  GDP (constant 2010 US$)  \
# 27                        Burundi    BDI  2017.0             2.309167e+09
# 32       Central African Republic    CAF  2017.0             1.560913e+09
# 94                        Liberia    LBR  2017.0             1.666984e+09
# 121                         Niger    NER  2017.0             8.503683e+09
# 44   Democratic Republic of Congo    COD  2017.0             3.327760e+10
# ..                            ...    ...     ...                      ...
# 238                     Venezuela    NaN     NaN                      NaN
# 239             Wallis and Futuna    NaN     NaN                      NaN
# 240                Western Sahara    NaN     NaN                      NaN
# 241                         World    NaN     NaN                      NaN
# 242                         Yemen    NaN     NaN                      NaN
#
#            gdp    Code_y  Year_y    population  gdp per capita
# 27    2.309167       BDI  2017.0  1.082700e+07      213.278588
# 32    1.560913       CAF  2017.0  4.596000e+06      339.624311
# 94    1.666984       LBR  2017.0  4.702000e+06      354.526588
# 121   8.503683       NER  2017.0  2.160200e+07      393.652575
# 44   33.277602       COD  2017.0  8.139900e+07      408.820771
# ..         ...       ...     ...           ...             ...
# 238        NaN       VEN  2017.0  2.940200e+07             NaN
# 239        NaN       WLF  2017.0  1.200000e+04             NaN
# 240        NaN       ESH  2017.0  5.530000e+05             NaN
# 241        NaN  OWID_WRL  2017.0  7.547859e+09             NaN
# 242        NaN       YEM  2017.0  2.783500e+07             NaN
#
# [243 rows x 9 columns]

# %%
px.bar(gdp_and_pop_2017.sort_values("gdp per capita"), x="Entity", y="gdp per capita")
# Out:
# <div>                            <div id="dc44752b-b6e0-425f-a4d5-270214c45232" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dc44752b-b6e0-425f-a4d5-270214c45232")) {                    Plotly.newPlot(                        "dc44752b-b6e0-425f-a4d5-270214c45232",                        [{"alignmentgroup":"True","hovertemplate":"Entity=%{x}<br>gdp per capita=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Burundi","Central African Republic","Liberia","Niger","Democratic Republic of Congo","Madagascar","Sierra Leone","Gambia","Malawi","Mozambique","Ethiopia","Togo","Afghanistan","Guinea-Bissau","Burkina Faso","Uganda","Haiti","Mali","Comoros","Nepal","Rwanda","Chad","Benin","Guinea","Tanzania","Tajikistan","Kyrgyzstan","Zimbabwe","Bangladesh","Cambodia","Kenya","Pakistan","Senegal","Sao Tome and Principe","Mauritania","Solomon Islands","Cameroon","Myanmar","Lesotho","Cote d'Ivoire","Zambia","Laos","Kiribati","Ghana","Vietnam","Moldova","Sudan","Nicaragua","India","Uzbekistan","Honduras","Papua New Guinea","Nigeria","Bolivia","Palestine","Congo","Timor","Egypt","Vanuatu","Ukraine","Philippines","Guatemala","Marshall Islands","Bhutan","Jordan","Morocco","El Salvador","Angola","Cape Verde","Tuvalu","Paraguay","Samoa","Guyana","Sri Lanka","Georgia","Mongolia","Tonga","Indonesia","Armenia","Belize","Tunisia","Fiji","Jamaica","Eswatini","Serbia","Algeria","Albania","Ecuador","North Macedonia","Iraq","Azerbaijan","Bosnia and Herzegovina","Thailand","Namibia","Peru","Belarus","Lebanon","Saint Vincent and the Grenadines","Dominica","Iran","Libya","China","Turkmenistan","Dominican Republic","South Africa","Colombia","Montenegro","Botswana","Maldives","Suriname","Bulgaria","Saint Lucia","Grenada","Gabon","Costa Rica","Mauritius","Mexico","Argentina","Kazakhstan","Romania","Brazil","Panama","Equatorial Guinea","Russia","Malaysia","Nauru","Palau","Seychelles","Uruguay","Antigua and Barbuda","Chile","Turkey","Croatia","Trinidad and Tobago","Latvia","Hungary","Poland","Oman","Barbados","Lithuania","Saint Kitts and Nevis","Estonia","Slovakia","Saudi Arabia","Cyprus","Bahrain","Czechia","Portugal","Greece","Slovenia","South Korea","Bahamas","Malta","Brunei","Spain","Kuwait","Italy","Israel","Hong Kong","New Zealand","United Arab Emirates","United Kingdom","Andorra","France","Belgium","Germany","Finland","Japan","Austria","Iceland","Canada","San Marino","United States","Netherlands","Singapore","Macao","Australia","Sweden","Denmark","Qatar","Ireland","Switzerland","Norway","Luxembourg","Kosovo","Africa","American Samoa","Anguilla","Aruba","Asia","Bermuda","Bonaire Sint Eustatius and Saba","British Virgin Islands","Cayman Islands","Channel Islands","Cook Islands","Cuba","Curacao","Djibouti","Eritrea","Europe","Faeroe Islands","Falkland Islands","French Guiana","French Polynesia","Gibraltar","Greenland","Guadeloupe","Guam","Isle of Man","Latin America","Liechtenstein","Martinique","Mayotte","Micronesia (country)","Monaco","Montserrat","New Caledonia","Niue","North America","North Korea","Northern Mariana Islands","Oceania","Puerto Rico","Reunion","Saint Barthlemy","Saint Helena","Saint Martin (French part)","Saint Pierre and Miquelon","Sint Maarten (Dutch part)","Somalia","South Sudan","Syria","Taiwan","Tokelau","Turks and Caicos Islands","United States Virgin Islands","Vatican","Venezuela","Wallis and Futuna","Western Sahara","World","Yemen"],"xaxis":"x","y":[213.27858761188048,339.62431132785247,354.5265876589813,393.6525754495546,408.82077087232886,421.8895132896171,466.7321194998571,506.8967392330487,512.6562214324799,537.4346092917973,542.3930828490611,584.8597238590712,605 ...

# %%
# this isn't what we want, and it's only for one year
gdp_and_pop = pd.merge(left=gdp, right=pop, left_on="Entity", right_on="Entity", how="inner")
gdp_and_pop
# Out:
#               Entity Code_x  Year_x  GDP (constant 2010 US$)        gdp  \
# 0        Afghanistan    AFG    2002             8.013233e+09   8.013233
# 1        Afghanistan    AFG    2002             8.013233e+09   8.013233
# 2        Afghanistan    AFG    2002             8.013233e+09   8.013233
# 3        Afghanistan    AFG    2002             8.013233e+09   8.013233
# 4        Afghanistan    AFG    2002             8.013233e+09   8.013233
# ...              ...    ...     ...                      ...        ...
# 1904165     Zimbabwe    ZWE    2017             1.532981e+10  15.329811
# 1904166     Zimbabwe    ZWE    2017             1.532981e+10  15.329811
# 1904167     Zimbabwe    ZWE    2017             1.532981e+10  15.329811
# 1904168     Zimbabwe    ZWE    2017             1.532981e+10  15.329811
# 1904169     Zimbabwe    ZWE    2017             1.532981e+10  15.329811
#
#         Code_y  Year_y  population
# 0          AFG    1800     3280000
# 1          AFG    1801     3280000
# 2          AFG    1802     3280000
# 3          AFG    1803     3280000
# 4          AFG    1804     3280000
# ...        ...     ...         ...
# 1904165    ZWE    2015    13815000
# 1904166    ZWE    2016    14030000
# 1904167    ZWE    2017    14237000
# 1904168    ZWE    2018    14439000
# 1904169    ZWE    2019    14645000
#
# [1904170 rows x 8 columns]

# %%
gdp_and_pop.query('Entity == "Afghanistan"')
#Note below that this gives us duplicate entries
# Out:
#            Entity Code_x  Year_x  GDP (constant 2010 US$)        gdp Code_y  \
# 0     Afghanistan    AFG    2002             8.013233e+09   8.013233    AFG
# 1     Afghanistan    AFG    2002             8.013233e+09   8.013233    AFG
# 2     Afghanistan    AFG    2002             8.013233e+09   8.013233    AFG
# 3     Afghanistan    AFG    2002             8.013233e+09   8.013233    AFG
# 4     Afghanistan    AFG    2002             8.013233e+09   8.013233    AFG
# ...           ...    ...     ...                      ...        ...    ...
# 3515  Afghanistan    AFG    2017             2.196941e+10  21.969414    AFG
# 3516  Afghanistan    AFG    2017             2.196941e+10  21.969414    AFG
# 3517  Afghanistan    AFG    2017             2.196941e+10  21.969414    AFG
# 3518  Afghanistan    AFG    2017             2.196941e+10  21.969414    AFG
# 3519  Afghanistan    AFG    2017             2.196941e+10  21.969414    AFG
#
#       Year_y  population
# 0       1800     3280000
# 1       1801     3280000
# 2       1802     3280000
# 3       1803     3280000
# 4       1804     3280000
# ...      ...         ...
# 3515    2015    34414000
# 3516    2016    35383000
# 3517    2017    36296000
# 3518    2018    37172000
# 3519    2019    38042000
#
# [3520 rows x 8 columns]

# %%
#To fix this, join by Entity and Year
pd.merge(left=gdp, right=pop, left_on=["Entity","Year"], right_on=["Entity","Year"], how="outer")

#do it as a left join so that we only preserve the GDP and population
gdp_and_pop_real = pd.merge(left=gdp, right=pop, left_on=["Entity","Year"], right_on=["Entity","Year"], how="left")
gdp_and_pop_real
# Out:
#            Entity Code_x  Year  GDP (constant 2010 US$)        gdp Code_y  \
# 0     Afghanistan    AFG  2002             8.013233e+09   8.013233    AFG
# 1     Afghanistan    AFG  2003             8.689884e+09   8.689884    AFG
# 2     Afghanistan    AFG  2004             8.781610e+09   8.781610    AFG
# 3     Afghanistan    AFG  2005             9.762979e+09   9.762979    AFG
# 4     Afghanistan    AFG  2006             1.030523e+10  10.305228    AFG
# ...           ...    ...   ...                      ...        ...    ...
# 8864     Zimbabwe    ZWE  2013             1.418193e+10  14.181927    ZWE
# 8865     Zimbabwe    ZWE  2014             1.448359e+10  14.483588    ZWE
# 8866     Zimbabwe    ZWE  2015             1.472830e+10  14.728302    ZWE
# 8867     Zimbabwe    ZWE  2016             1.481899e+10  14.818986    ZWE
# 8868     Zimbabwe    ZWE  2017             1.532981e+10  15.329811    ZWE
#
#       population
# 0     22601000.0
# 1     23681000.0
# 2     24727000.0
# 3     25654000.0
# 4     26433000.0
# ...          ...
# 8864  13350000.0
# 8865  13587000.0
# 8866  13815000.0
# 8867  14030000.0
# 8868  14237000.0
#
# [8869 rows x 7 columns]

# %%
gdp_and_pop_real["gdp_per_capita"] = gdp_and_pop_real["GDP (constant 2010 US$)"] / gdp_and_pop_real["population"]
gdp_and_pop_real
# Out:
#            Entity Code_x  Year  GDP (constant 2010 US$)        gdp Code_y  \
# 0     Afghanistan    AFG  2002             8.013233e+09   8.013233    AFG
# 1     Afghanistan    AFG  2003             8.689884e+09   8.689884    AFG
# 2     Afghanistan    AFG  2004             8.781610e+09   8.781610    AFG
# 3     Afghanistan    AFG  2005             9.762979e+09   9.762979    AFG
# 4     Afghanistan    AFG  2006             1.030523e+10  10.305228    AFG
# ...           ...    ...   ...                      ...        ...    ...
# 8864     Zimbabwe    ZWE  2013             1.418193e+10  14.181927    ZWE
# 8865     Zimbabwe    ZWE  2014             1.448359e+10  14.483588    ZWE
# 8866     Zimbabwe    ZWE  2015             1.472830e+10  14.728302    ZWE
# 8867     Zimbabwe    ZWE  2016             1.481899e+10  14.818986    ZWE
# 8868     Zimbabwe    ZWE  2017             1.532981e+10  15.329811    ZWE
#
#       population  gdp_per_capita
# 0     22601000.0      354.552149
# 1     23681000.0      366.955940
# 2     24727000.0      355.142564
# 3     25654000.0      380.563610
# 4     26433000.0      389.862222
# ...          ...             ...
# 8864  13350000.0     1062.316603
# 8865  13587000.0     1065.988675
# 8866  13815000.0     1066.109450
# 8867  14030000.0     1056.235654
# 8868  14237000.0     1076.758501
#
# [8869 rows x 8 columns]

# %%
#Now we can explore the history of various categories
px.line( gdp_and_pop_real.query('Entity == "India"'), x="Year", y="gdp_per_capita")
# Out:
# <div>                            <div id="1b770dba-c451-441b-a7f9-0fb55f8176da" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1b770dba-c451-441b-a7f9-0fb55f8176da")) {                    Plotly.newPlot(                        "1b770dba-c451-441b-a7f9-0fb55f8176da",                        [{"hovertemplate":"Year=%{x}<br>gdp_per_capita=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017],"xaxis":"x","y":[303.5111375959387,308.58158082129415,311.2377661639371,323.17774076955897,340.14465530016287,324.361527659885,317.4971864661756,335.26004635459265,339.37125770721957,353.8622138314205,363.9977614687113,361.7179966614814,351.53353921078764,354.7646643466695,350.6954966238948,373.99908788994935,371.5565994941163,389.4846685385686,402.4255173787677,372.69421643887915,388.7159772995302,402.5981890918714,407.002739011795,426.6526504087595,432.9006533041787,445.464864374309,456.4910096539795,464.34021672891004,498.23425677842414,516.8400505892723,534.2321485707743,528.9778188028095,546.9122757961491,561.7155929231328,587.5898472524461,620.082699454377,654.3763113318446,668.2686811544697,696.6620247811787,744.7190287417634,759.7700106437389,782.7714673618364,798.9348484995256,847.6195849696252,900.1184309051717,968.2750424785778,1041.7487018388704,1126.720722891297,1153.5378169545963,1233.8283032735924,1342.171780017339,1412.9459302269238,1471.8050128868447,1547.3831238002813,1643.1142606548526,1757.3638053406808,1861.9444357196362,1964.284310117216],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22222 ...

# %%
#ok, let's try to get how much each economy has grown since 1960
gdp_and_pop_by_entity = gdp_and_pop_real.set_index("Entity")
gdp_and_pop_by_entity
# Out:
#             Code_x  Year  GDP (constant 2010 US$)        gdp Code_y  \
# Entity
# Afghanistan    AFG  2002             8.013233e+09   8.013233    AFG
# Afghanistan    AFG  2003             8.689884e+09   8.689884    AFG
# Afghanistan    AFG  2004             8.781610e+09   8.781610    AFG
# Afghanistan    AFG  2005             9.762979e+09   9.762979    AFG
# Afghanistan    AFG  2006             1.030523e+10  10.305228    AFG
# ...            ...   ...                      ...        ...    ...
# Zimbabwe       ZWE  2013             1.418193e+10  14.181927    ZWE
# Zimbabwe       ZWE  2014             1.448359e+10  14.483588    ZWE
# Zimbabwe       ZWE  2015             1.472830e+10  14.728302    ZWE
# Zimbabwe       ZWE  2016             1.481899e+10  14.818986    ZWE
# Zimbabwe       ZWE  2017             1.532981e+10  15.329811    ZWE
#
#              population  gdp_per_capita
# Entity
# Afghanistan  22601000.0      354.552149
# Afghanistan  23681000.0      366.955940
# Afghanistan  24727000.0      355.142564
# Afghanistan  25654000.0      380.563610
# Afghanistan  26433000.0      389.862222
# ...                 ...             ...
# Zimbabwe     13350000.0     1062.316603
# Zimbabwe     13587000.0     1065.988675
# Zimbabwe     13815000.0     1066.109450
# Zimbabwe     14030000.0     1056.235654
# Zimbabwe     14237000.0     1076.758501
#
# [8869 rows x 7 columns]

# %%
#make a temporary dataframe as our base economic state
#Divide all further dates by this
gdp_per_capitas_1960 = gdp_and_pop_by_entity.query("Year == 1960")[["gdp_per_capita"]]
gdp_per_capitas_1960
# Out:
#                gdp_per_capita
# Entity
# Algeria           2480.954892
# Argentina         5642.704253
# Australia        19452.581069
# Austria          12987.795692
# Bahamas          17659.437251
# ...                       ...
# United States    16484.868935
# Uruguay           5473.869009
# Venezuela        12456.963693
# Zambia            1495.596123
# Zimbabwe           890.482345
#
# [90 rows x 1 columns]

# %%
gdp_and_pop_by_entity["gdp_per_capita_ratio"] = gdp_and_pop_by_entity["gdp_per_capita"] / gdp_per_capitas_1960["gdp_per_capita"]
gdp_and_pop_by_entity
# Out:
#             Code_x  Year  GDP (constant 2010 US$)        gdp Code_y  \
# Entity
# Afghanistan    AFG  2002             8.013233e+09   8.013233    AFG
# Afghanistan    AFG  2003             8.689884e+09   8.689884    AFG
# Afghanistan    AFG  2004             8.781610e+09   8.781610    AFG
# Afghanistan    AFG  2005             9.762979e+09   9.762979    AFG
# Afghanistan    AFG  2006             1.030523e+10  10.305228    AFG
# ...            ...   ...                      ...        ...    ...
# Zimbabwe       ZWE  2013             1.418193e+10  14.181927    ZWE
# Zimbabwe       ZWE  2014             1.448359e+10  14.483588    ZWE
# Zimbabwe       ZWE  2015             1.472830e+10  14.728302    ZWE
# Zimbabwe       ZWE  2016             1.481899e+10  14.818986    ZWE
# Zimbabwe       ZWE  2017             1.532981e+10  15.329811    ZWE
#
#              population  gdp_per_capita  gdp_per_capita_ratio
# Entity
# Afghanistan  22601000.0      354.552149                   NaN
# Afghanistan  23681000.0      366.955940                   NaN
# Afghanistan  24727000.0      355.142564                   NaN
# Afghanistan  25654000.0      380.563610                   NaN
# Afghanistan  26433000.0      389.862222                   NaN
# ...                 ...             ...                   ...
# Zimbabwe     13350000.0     1062.316603              1.192968
# Zimbabwe     13587000.0     1065.988675              1.197091
# Zimbabwe     13815000.0     1066.109450              1.197227
# Zimbabwe     14030000.0     1056.235654              1.186139
# Zimbabwe     14237000.0     1076.758501              1.209186
#
# [8869 rows x 8 columns]

# %%
gdp_and_pop_by_entity_2 = gdp_and_pop_by_entity.reset_index()

#px.line(gdp_and_pop_by_entity)

# %%
gdp_and_pop_by_entity_3 = gdp_and_pop_by_entity_2.dropna()

# %%
px.line(gdp_and_pop_by_entity_3, x="Year", y="gdp_per_capita_ratio", color="Entity")
# Out:
# <div>                            <div id="45930f28-6d61-4f4e-972b-91bf07495ce1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("45930f28-6d61-4f4e-972b-91bf07495ce1")) {                    Plotly.newPlot(                        "45930f28-6d61-4f4e-972b-91bf07495ce1",                        [{"hovertemplate":"Entity=Algeria<br>Year=%{x}<br>gdp_per_capita_ratio=%{y}<extra></extra>","legendgroup":"Algeria","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Algeria","showlegend":true,"x":[1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017],"xaxis":"x","y":[1.0,0.8427584948993144,0.6603182272122079,0.8650847931793704,0.8924521966367636,0.9229998660967261,0.8546799995022013,0.9092582070271406,0.9787435721813822,1.031246004017138,1.0913646048985677,0.9412114764001974,1.1668468697738423,1.1786477045681885,1.2325441841857114,1.2589474222085815,1.3263579569545947,1.3566433944606708,1.4391754991915238,1.501505517250363,1.468184654571373,1.4663078939109977,1.5121716372837815,1.5448101385343287,1.581699278189698,1.591378118758679,1.5514061766827925,1.4970010213684908,1.4414680401424698,1.4651514144751583,1.4394333769342267,1.3876296881624577,1.3797848985587313,1.3210912072698602,1.2823807604266237,1.305931230928261,1.3358765990650348,1.3289116072343106,1.375869773645656,1.3999598038809997,1.433815548638343,1.4576972537483093,1.5199883264538492,1.6087998726540536,1.6560361528227197,1.7296398471709526,1.7331055988189388,1.7639800546269548,1.776290852583967,1.7744757827095632,1.8060958944919583,1.823654186661197,1.8487388922035781,1.8622459372465419,1.8938784182925905,1.9253838770579645,1.9485555261179317,1.941558023073919],"yaxis":"y","type":"scattergl"},{"hovertemplate":"Entity=Argentina<br>Year=%{x}<br>gdp_per_capita_ratio=%{y}<extra></extra>","legendgroup":"Argentina","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Argentina","showlegend":true,"x":[1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017],"xaxis":"x","y":[1.0,1.0373123302388334,1.012137642160708,0.9434257529385448,1.0230489007476342,1.1140279161639883,1.0902459747007722,1.108537298259042,1.1449938929743613,1.2371344301198226,1.255435502867129,1.3057470177161772,1.3058557997869467,1.3209793425275433,1.371850693279539,1.350040129400428,1.302697954407848,1.372338078574193,1.291127779012024,1.4018769430604257,1.4377834570097294,1.3348313007653678,1.2485707045734675,1.2762559226319174,1.283646814914058,1.167455443770481,1.2395869794995045,1.2558187473528617,1.2049679732877003,1.0980333146673869,1.056217314793025,1.1734882089276604,1.2959815229487501,1.3547158113558424,1.4157340330804329,1.3586690143504947,1.4167547758102406,1.514013659912697,1.5546047541831485,1.485334642014705,1.4574687858945394,1.378074222453303,1.2147098478247467,1.3079617818604272,1.4110976156529451,1.520166464845793,1.6259001994812854,1.754758896175816,1.8079126965199217,1.6839787091651512,1.8357601761066524,1.926009917593455,1.8863819034403215,1.9115662795958257,1.8442179251102264,1.8753657031156967,1.8228625307548867,1.8567597821464523],"yaxis":"y","type":"scattergl"},{"hovertemplate":"Entity=Australia<br>Year=%{x}<br>gdp_per_capita_ratio=%{y}<extra></extra>","legendgroup":"Australia","line":{"color":"#00cc96","dash":" ...
